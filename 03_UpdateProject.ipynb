# %% [markdown]
# <a href="https://colab.research.google.com/github/TMhdSofyan/Unsupervised_Learning/blob/main/03_UpdateProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install jcopml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 KB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.4 MB/s eta 0:00:00
# ...
#   Created wheel for jcopml: filename=jcopml-1.2.2-py2.py3-none-any.whl size=32194 sha256=a3d9f642bc96ce45240744f884fd9f623b1952fd23d8441fa7e3a6524dc290fb
#   Stored in directory: /root/.cache/pip/wheels/a6/1c/91/32f7a6b0a9d6bbcef17a7fc0d065f9a9b8d9904551b377b64d
# Successfully built jcopml
# ...

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value
from jcopml.feature_importance import mean_score_decrease

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Newdata_Pete590.csv')
df.head()
# Out:
#      DEPTH         FZI        CGR      DRHO        DT5         GR      HNPO  \
# 0  2410.08  211.121914  31.992576  0.034071  86.073454  47.128474  0.184824
# 1  2410.20  288.431455  31.976041  0.025724  86.340619  48.285009  0.183564
# 2  2410.39  274.592462  36.236242  0.009850  87.020905  50.670716  0.181900
# 3  2410.60  497.852972  42.122592  0.003631  87.951610  53.894521  0.173462
# 4  2410.82  184.453837  42.361279  0.014313  88.442537  54.477657  0.188333
#
#         LLD      LLHR       LLS      MRES      MSFC      NPHI      NPOR  \
# 0  1.484896  1.989065  1.370871  0.067983  1.299775  0.179966  0.179166
# 1  1.479856  1.984340  1.344729  0.067904  1.278673  0.184376  0.181292
# 2  1.491390  1.827785  1.336755  0.067821  1.246173  0.187421  0.179666
# 3  1.559632  1.893686  1.371531  0.067900  1.095846  0.185625  0.182018
# 4  1.590263  2.136641  1.372559  0.067900  1.328147  0.184468  0.185889
#
#        POTA      RHOB        SP      THOR      URAN
# ...

# %%
df.describe().T
# Out:
#        count         mean         std          min          25%          50%  \
# DEPTH  212.0  2428.359057   10.730660  2410.080000  2419.010000  2428.095000
# FZI    212.0   456.224651  400.791802     4.503497    54.033758   364.007985
# CGR    212.0    45.024872   24.695799    14.161406    27.581358    35.421470
# DRHO   212.0     0.026687    0.013808     0.000285     0.018462     0.024900
# DT5    212.0    80.306421    3.967383    73.306692    77.275580    80.108254
# GR     212.0    55.623111   26.471878    27.676605    36.614972    47.948590
# HNPO   212.0     0.154084    0.038952     0.086823     0.128285     0.149612
# LLD    212.0     2.199655    1.688266     1.075735     1.250791     1.488671
# LLHR   212.0     2.912141    2.730197     1.151446     1.525993     1.700839
# LLS    212.0     2.081772    1.666483     0.878654     1.052103     1.323578
# MRES   212.0     0.067091    0.000481     0.066300     0.066700     0.067100
# ...

# %%
plt.figure(figsize = (17, 13))
sns.heatmap(df.corr(), cmap= "crest", cbar= False, annot= True, square= True, fmt= '.1')
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/corrplot_600dpi.png', dpi = 600)

# %%
# more detailed look at the Univariate plots
df.hist(bins=30, figsize=(15,13))
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Histogram_600dpi.png', dpi = 600)

# %%
from sklearn.preprocessing import PowerTransformer

# %%
df = df.drop(columns = ['DEPTH', 'DRHO', 'DT5', 'GR', 'HNPO', 'LLD',
                         'LLS', 'MRES', 'MSFC', 'POTA', 'RHOB', 'SP',
                         'URAN'])

# %%
pt = PowerTransformer(method='yeo-johnson')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FZI     212 non-null    float64
#  1   CGR     212 non-null    float64
#  2   LLHR    212 non-null    float64
#  3   NPHI    212 non-null    float64
#  4   NPOR    212 non-null    float64
#  5   THOR    212 non-null    float64
# dtypes: float64(6)
# memory usage: 10.1 KB

# %%
pt.fit(df[df])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-d75cdbc55831> in <cell line: 1>()
# ----> 1 pt.fit(df[df])
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3490         # Do we have a (boolean) DataFrame?
#    3491         if isinstance(key, DataFrame):
# -> 3492             return self.where(key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10962         try_cast=lib.no_default,
# ...

# %%
df[df2] = pt.transform(df[df2])

# %%
# more detailed look at the Univariate plots
df.hist(bins=30, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'CGR'}>, <Axes: title={'center': 'DT5'}>,
#         <Axes: title={'center': 'GR'}>],
#        [<Axes: title={'center': 'LLD'}>,
#         <Axes: title={'center': 'NPHI'}>,
#         <Axes: title={'center': 'RHOB'}>],
#        [<Axes: title={'center': 'SP'}>, <Axes: title={'center': 'FZI'}>,
#         <Axes: >]], dtype=object)

# %%
X = df.drop(columns="FZI")
y = df.FZI

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((148, 18), (64, 18), (148,), (64,))

# %%
# more detailed look at the Univariate plots
X.hist(bins=30, figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'DEPTH'}>,
#         <Axes: title={'center': 'CGR'}>,
#         <Axes: title={'center': 'DRHO'}>,
#         <Axes: title={'center': 'DT5'}>],
#        [<Axes: title={'center': 'GR'}>, <Axes: title={'center': 'HNPO'}>,
#         <Axes: title={'center': 'LLD'}>,
#         <Axes: title={'center': 'LLHR'}>],
#        [<Axes: title={'center': 'LLS'}>,
#         <Axes: title={'center': 'MRES'}>,
#         <Axes: title={'center': 'MSFC'}>,
#         <Axes: title={'center': 'NPHI'}>],
#        [<Axes: title={'center': 'NPOR'}>,
#         <Axes: title={'center': 'POTA'}>,
#         <Axes: title={'center': 'RHOB'}>, <Axes: title={'center': 'SP'}>],
#        [<Axes: title={'center': 'THOR'}>,
#         <Axes: title={'center': 'URAN'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# # **Random Forest Model**

# %%
from sklearn.model_selection import RandomizedSearchCV
from jcopml.tuning import random_search_params as rsp
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gs
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling='minmax', transform= 'yeo-johnson' , poly = 3), X.columns )])


from sklearn.ensemble import RandomForestRegressor
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', RandomForestRegressor(n_jobs=-1, random_state=42))
])

model_RF = RandomizedSearchCV(pipeline, rsp.rf_poly_params, cv=3, n_iter=50,  n_jobs=-1, verbose=1, random_state=42)
model_RF.fit(X_train, y_train)

print(model_RF.best_params_)
print(model_RF.score(X_train, y_train), model_RF.best_score_, model_RF.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/jcopml/pipeline/_pipeline.py:66: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 6 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
# ...

# %%
from jcopml.plot import plot_actual_vs_prediction, plot_residual
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model_RF)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Histogram_600dpi.png', dpi = 600)

# %%
plot_residual(X_train, y_train, X_test, y_test, model_RF)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Residual_RF_600dpi.png', dpi = 600)

# %% [markdown]
# # **XGBOOST Model**

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly = 2), X.columns )])


from xgboost import XGBRegressor
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', XGBRegressor(n_jobs=-1, random_state=42))
])


model_XGB = RandomizedSearchCV(pipeline, rsp.xgb_params, cv=3, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model_XGB.fit(X_train, y_train)

print(model_XGB.best_params_)
print(model_XGB.score(X_train, y_train), model_XGB.best_score_, model_XGB.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'algo__colsample_bytree': 0.36500400286262713, 'algo__gamma': 5, 'algo__learning_rate': 0.024089182524468254, 'algo__max_depth': 1, 'algo__n_estimators': 166, 'algo__reg_alpha': 0.004763991596630582, 'algo__reg_lambda': 0.16873495104568947, 'algo__subsample': 0.7680773870803905}
# 0.8436808736503478 0.6974908319456569 0.7196990771986024

# %%
from jcopml.plot import plot_actual_vs_prediction, plot_residual
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model_XGB)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Actual_XGB_600dpi.png', dpi = 600)

# %%
plot_residual(X_train, y_train, X_test, y_test, model_XGB)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Residual_XGB_600dpi.png', dpi = 600)

# %% [markdown]
# # **SVM Model**

# %%
from sklearn.svm import SVR
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling='minmax'), X.columns )])

pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])


model_SVM = RandomizedSearchCV(pipeline, rsp.svm_params, cv=3, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model_SVM.fit(X_train, y_train)

print(model_SVM.best_params_)
print(model_SVM.score(X_train, y_train), model_SVM.best_score_, model_SVM.score(X_test, y_test))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'algo__C': 210.51180519608752, 'algo__gamma': 0.68122338968603}
# 0.7040877153276786 0.609010798359711 0.6112082639293817

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model_SVM)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Actual_SVM_600dpi.png', dpi = 600)

# %%
plot_residual(X_train, y_train, X_test, y_test, model_SVM)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Residual_SVM_600dpi.png', dpi = 600)

# %%
plot_residual(X_train, y_train, X_test, y_test, model_SVM)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Residual_SVM_600dpi.png', dpi = 600)

# %% [markdown]
# # **ANN Model**

# %%
from sklearn.neural_network import MLPRegressor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling='standard', poly = 2, transform= 'yeo-johnson'), X.columns )])


pipeline = Pipeline([
    ('prep', preprocessor),
    ('mlp', MLPRegressor(random_state=42))
])

parameter = {
    "mlp__alpha": [0.0001, 0.0003, 0.001, 0.003, 0.01, 0.03],
    "mlp__hidden_layer_sizes": [(16, 8, 4), (16, 4), (8, 4), (13, 8, 2), (32, 16, 2), (64, 32, 16, 8, 4, 2)],
    "mlp__learning_rate_init": [0.001, 0.005, 0.01],
    "mlp__activation": ["identity"]
}

model_ANN = RandomizedSearchCV(pipeline, parameter, cv=3, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model_ANN.fit(X_train, y_train)

print(model_ANN.best_params_)
print(model_ANN.score(X_train, y_train), model_ANN.best_score_, model_ANN.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/jcopml/pipeline/_pipeline.py:66: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'mlp__learning_rate_init': 0.001, 'mlp__hidden_layer_sizes': (64, 32, 16, 8, 4, 2), 'mlp__alpha': 0.003, 'mlp__activation': 'identity'}
# 0.8232041181212876 0.515545171208379 0.7443739553540686
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model_ANN)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Actual_ANN_600dpi.png', dpi = 600)

# %%
plot_residual(X_train, y_train, X_test, y_test, model_ANN)
plt.savefig('/content/drive/MyDrive/01_Project_Reservoir_Description/Data/Residual_ANN_600dpi.png', dpi = 600)

# %%
from jcopml.feature_importance import mean_loss_decrease, mean_score_decrease

# %%
df_imp = mean_score_decrease(X_train, y_train, model_RF, plot=True, topk = 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
sns.heatmap(df.corr(), cmap= "YlGnBu", cbar= False, annot= True, square= True, fmt= '.1')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['DEPTH', 'FZI', 'CGR', 'DRHO', 'DT5', 'GR', 'HNPO', 'LLD', 'LLHR',
#        'LLS', 'MRES', 'MSFC', 'NPHI', 'NPOR', 'POTA', 'RHOB', 'SP', 'THOR',
#        'URAN'],
#       dtype='object')

# %%
df2 = df.drop(columns = ['DEPTH', 'DRHO', 'DT5', 'GR', 'HNPO', 'LLD',
                         'LLS', 'MRES', 'MSFC', 'POTA', 'RHOB', 'SP',
                         'URAN'])

# %%
df2.head()
# Out:
#           FZI        CGR      LLHR      NPHI      NPOR      THOR
# 0  211.121914  31.992576  1.989065  0.179966  0.179166  2.646898
# 1  288.431455  31.976041  1.984340  0.184376  0.181292  2.688867
# 2  274.592462  36.236242  1.827785  0.187421  0.179666  2.949177
# 3  497.852972  42.122592  1.893686  0.185625  0.182018  3.316663
# 4  184.453837  42.361279  2.136641  0.184468  0.185889  3.220796

# %%
X = df2.drop(columns="FZI")
y = df2.FZI

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((148, 5), (64, 5), (148,), (64,))

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling='minmax', transform= 'yeo-johnson' , poly = 2), X.columns )])


from sklearn.ensemble import RandomForestRegressor
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', RandomForestRegressor(n_jobs=-1, random_state=42))
])

model_RF = RandomizedSearchCV(pipeline, rsp.rf_poly_params, cv=3, n_iter=50,  n_jobs=-1, verbose=1, random_state=42)
model_RF.fit(X_train, y_train)

print(model_RF.best_params_)
print(model_RF.score(X_train, y_train), model_RF.best_score_, model_RF.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/jcopml/pipeline/_pipeline.py:66: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'algo__max_depth': 21, 'algo__max_features': 0.26364247048639056, 'algo__min_samples_leaf': 1, 'algo__n_estimators': 175, 'prep__numeric__poly__degree': 2, 'prep__numeric__poly__interaction_only': False}
# 0.9663099484960201 0.7458673177016811 0.746867163345839

# %%
from jcopml.plot import plot_actual_vs_prediction, plot_residual
plot_actual_vs_prediction(X_train, y_train, X_test, y_test, model_RF)

# %%
from sklearn.svm import SVR

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(scaling='robust', transform = 'yeo-johnson', poly = 3), X.columns )])

pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVR(max_iter=500))
])


model_SVM = RandomizedSearchCV(pipeline, rsp.svm_poly_params, cv=3, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model_SVM.fit(X_train, y_train)

print(model_SVM.best_params_)
print(model_SVM.score(X_train, y_train), model_SVM.best_score_, model_SVM.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/jcopml/pipeline/_pipeline.py:66: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'algo__C': 276.03912956530075, 'algo__gamma': 0.04293322340412749, 'prep__numeric__poly__degree': 3, 'prep__numeric__poly__interaction_only': False}
# 0.8116210983759284 0.7112945228656965 0.6595048243839502
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
df_imp = mean_score_decrease(X_train, y_train, model_SVM, plot=True, topk = 10)

# %%
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly = 2, transform='yeo-johnson', scaling='robust'), X.columns )])


from xgboost import XGBRegressor
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', XGBRegressor(n_jobs=-1, random_state=42))
])


model_XGB = RandomizedSearchCV(pipeline, rsp.xgb_poly_params, cv=3, n_iter=50, n_jobs=-1, verbose=1, random_state=42)
model_XGB.fit(X_train, y_train)

print(model_XGB.best_params_)
print(model_XGB.score(X_train, y_train), model_XGB.best_score_, model_XGB.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.9/dist-packages/jcopml/pipeline/_pipeline.py:66: UserWarning: Transformer has default standardization, so the scaling argument is neglected
#   warn("Transformer has default standardization, so the scaling argument is neglected")
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# {'algo__colsample_bytree': 0.48875051677790426, 'algo__gamma': 1, 'algo__learning_rate': 0.11208547084229371, 'algo__max_depth': 10, 'algo__n_estimators': 191, 'algo__reg_alpha': 7.852755494724264, 'algo__reg_lambda': 0.008532678095658717, 'algo__subsample': 0.3453032172664104, 'prep__numeric__poly__degree': 2, 'prep__numeric__poly__interaction_only': True}
# 0.9998539526499025 0.7734441664541207 0.7324224506966399
